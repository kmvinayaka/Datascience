# %%
import numpy as np
import pandas as pd

# %pylab inline
import seaborn as sns
sns.set_style('darkgrid')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
names = ['mpg'
    ,  'cylinders'
    ,  'displacement'
    ,  'horsepower'
    ,  'weight'
    ,  'acceleration'
    ,  'model_year'
    ,  'origin'
    ,  'car_name'
]
df = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data", sep='\s+', names=names)
df['maker'] = df.car_name.map(lambda x: x.split()[0])
#print df['maker']
df.origin = df.origin.map({1: 'America', 2: 'Europe', 3: 'Asia'})
df=df.applymap(lambda x: np.nan if x == '?' else x).dropna()
df['horsepower'] = df.horsepower.astype(float)
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year   origin                   car_name      maker
# 0          70  America  chevrolet chevelle malibu  chevrolet
# 1          70  America          buick skylark 320      buick
# 2          70  America         plymouth satellite   plymouth
# 3          70  America              amc rebel sst        amc
# 4          70  America                ford torino       ford

# %%
sns.factorplot(data=df, x="model_year", y="mpg")
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.factorplot(data=df, x="model_year", y="acceleration", col="origin")

# %%
sns.factorplot(data=df, x="model_year", y="mpg", col="origin")

# %%
sns.factorplot(data=df, x="mpg", y="acceleration", col="origin",kind='bar')

# %%
g = sns.FacetGrid(df, col="origin")
g.map(sns.distplot, "mpg")

# %%
g = sns.FacetGrid(df, col="origin")
g.map(plt.scatter, "horsepower", "mpg")

# %%
g = sns.FacetGrid(df, col="origin")
g.map(sns.regplot, "horsepower", "mpg")
plt.xlim(0, 250)
plt.ylim(0, 60)
# Out:
# (0, 60)

# %%
df['tons'] = (df.weight/2000).astype(int)
g = sns.FacetGrid(df, col="origin", row="tons")
g.map(sns.kdeplot, "horsepower", "mpg")
plt.xlim(0, 250)
plt.ylim(0, 60)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\contour.py:967: UserWarning: The following kwargs were not used by contour: 'color'
#   s)
# (0, 60)

# %%
g = sns.FacetGrid(df, col="origin", row="tons")
g.map(plt.hist, "mpg", bins=np.linspace(0, 50, 11))

# %%
g = sns.pairplot(df[["mpg", "horsepower", "weight", "origin"]], hue="origin", diag_kind="hist")
for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45)

# %%
g = sns.PairGrid(df[["mpg", "horsepower", "weight", "origin"]], hue="origin")
g.map_upper(sns.regplot)
g.map_lower(sns.residplot)
g.map_diag(plt.hist)
for ax in g.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=45)
g.add_legend()
g.set(alpha=0.5)

# %%
sns.jointplot("mpg", "horsepower", data=df, kind='kde')

# %%
sns.jointplot("horsepower", "mpg", data=df, kind="reg")

# %%
g = sns.JointGrid(x="horsepower", y="mpg", data=df)
g.plot_joint(sns.regplot, order=2)
g.plot_marginals(sns.distplot)
